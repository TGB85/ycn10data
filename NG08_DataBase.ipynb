# %%
import pandas as pd

# %%
print ("hoi")
df = pd.read_csv("netflix_imdb.csv")
print (df)
print (df.columns)
for m in df["title"]:
    print (m)
#return "klein beetje insparatie!"
# Out:
# hoi
#                                  title  release_year rating  duration  \
# 0                 Dick Johnson Is Dead          2020  PG-13      90.0
# 1     My Little Pony: A New Generation          2021     PG      91.0
# 2                              Sankofa          1993  TV-MA     125.0
# 3                         The Starling          2021  PG-13     104.0
# 4                         Je Suis Karl          2021  TV-MA     127.0
# ...                                ...           ...    ...       ...
# 4041                             Zenda          2009  TV-14     120.0
# 4042                            Zodiac          2007      R     158.0
# 4043                        Zombieland          2009      R      88.0
# 4044                              Zoom          2006     PG      88.0
# 4045                            Zubaan          2015  TV-14     111.0
#
#                                              listed_in      tconst  \
# ...

# %%
print(df.title.head(25))

# %%
print ("hoi")
df = pd.read_csv("netflix_imdb.csv")

print (df.title.head(25))
# Out:
# hoi
# 0                                  Dick Johnson Is Dead
# 1                      My Little Pony: A New Generation
# 2                                               Sankofa
# 3                                          The Starling
# 4                                          Je Suis Karl
# 5                      Confessions of an Invisible Girl
# 6                                             Intrusion
# 7          Go! Go! Cory Carson: Chrissy Takes the Wheel
# 8                                                 Jeans
# 9                                             Grown Ups
# 10                                           Dark Skies
# 11                                             Paranoia
# 12                                      Ankahi Kahaniya
# 13                       The Father Who Moves Mountains
# 14                                                 Jaws
# 15                                               Jaws 2
# 16                                    Jaws: The Revenge
# ...
